# %%
# Bundles 2022 primary results for display in the MTFP Capitol Tracker
import pandas as pd

# %%
xl = pd.ExcelFile('./sos-data/2022/primary/2022-primary-legislative-results.xlsx')
sheets = xl.sheet_names

output = []
for sheet in sheets:
    dfi = xl.parse(sheet)
    reporting = dfi.iloc[:,0][1]
    time = dfi.iloc[:,0][2]
    district = dfi.iloc[:,0][5].replace('STATE SENATOR','S').replace('STATE REPRESENTATIVE','H').replace(' DISTRICT','D').replace(' ','-')

    data = dfi[5:].drop(dfi.columns[0], axis='columns').transpose()
    data.columns = data.iloc[0]
    data.drop(data.index[0], inplace=True)
    data.reset_index(inplace=True)
    output.append(list(data.apply(lambda row: ({
        'district': district,
        'party': row['County'].split('\n')[1],
        'candidate': row['County'].split('\n')[0],
        'votes': row['TOTALS'],
    }), axis=1)))
    
output
# Out:
# [[{'district': 'SD-1',
#    'party': 'Republican',
#    'candidate': 'MICHAEL J CUFFE',
#    'votes': 3973}],
#  [{'district': 'SD-4',
#    'party': 'Republican',
#    'candidate': 'JOHN FULLER',
#    'votes': 2082},
#   {'district': 'SD-4',
#    'party': 'Republican',
#    'candidate': 'LEE HUESTIS',
#    'votes': 1590}],
#  [{'district': 'SD-4',
#    'party': 'Democrat',
#    'candidate': 'KYLE WATERMAN',
#    'votes': 844}],
#  [{'district': 'SD-5',
#    'party': 'Republican',
#    'candidate': 'MARK NOLAND',
#    'votes': 2967},
#   {'district': 'SD-5',
#    'party': 'Republican',
#    'candidate': 'ROB TRACY',
#    'votes': 1887}],
#  [{'district': 'SD-8',
#    'party': 'Republican',
#    'candidate': 'RICK JENNISON',
#    'votes': 1037}],
#  [{'district': 'SD-8',
#    'party': 'Democrat',
#    'candidate': 'SUSAN A WEBBER',
#    'votes': 1497}],
#  [{'district': 'SD-9',
#    'party': 'Republican',
#    'candidate': 'BRUCE "BUTCH" GILLESPIE',
#    'votes': 4160}],
#  [{'district': 'SD-11',
#    'party': 'Republican',
#    'candidate': 'DANIEL EMRICH',
#    'votes': 2201}],
#  [{'district': 'SD-11',
#    'party': 'Democrat',
#    'candidate': 'TOM JACOBSON',
#    'votes': 1171}],
#  [{'district': 'SD-12',
#    'party': 'Republican',
#    'candidate': 'WENDY MCKAMEY',
#    'votes': 1463},
#   {'district': 'SD-12',
#    'party': 'Republican',
#    'candidate': 'DESMA MEISSNER',
#    'votes': 787}],
#  [{'district': 'SD-12',
#    'party': 'Democrat',
#    'candidate': 'JACOB BACHMEIER',
#    'votes': 1175}],
#  [{'district': 'SD-13',
#    'party': 'Republican',
#    'candidate': 'JEREMY TREBAS',
#    'votes': 1688}],
#  [{'district': 'SD-13',
#    'party': 'Democrat',
#    'candidate': 'CASEY SCHREINER',
#    'votes': 953}],
#  [{'district': 'SD-14',
#    'party': 'Republican',
#    'candidate': 'RUSSEL E TEMPEL',
#    'votes': 2049},
#   {'district': 'SD-14',
#    'party': 'Republican',
#    'candidate': 'STEVEN CHVILICEK',
#    'votes': 1762}],
#  [{'district': 'SD-14',
#    'party': 'Democrat',
#    'candidate': 'DAVID H BREWER',
#    'votes': 982}],
#  [{'district': 'SD-15-UNEXPIRED-TERM',
#    'party': 'Republican',
#    'candidate': 'DAN BARTEL',
#    'votes': 4940}],
#  [{'district': 'SD-15-UNEXPIRED-TERM',
#    'party': 'Democrat',
#    'candidate': 'CINDY PALMER',
#    'votes': 875}],
#  [{'district': 'SD-19',
#    'party': 'Republican',
#    'candidate': 'KENNETH BOGNER',
#    'votes': 4624}],
#  [{'district': 'SD-20',
#    'party': 'Republican',
#    'candidate': 'GERALDINE CUSTER',
#    'votes': 2178},
#   {'district': 'SD-20',
#    'party': 'Republican',
#    'candidate': 'BARRY USHER',
#    'votes': 3417}],
#  [{'district': 'SD-22',
#    'party': 'Republican',
#    'candidate': 'DANIEL ZOLNIKOV',
#    'votes': 3279}],
#  [{'district': 'SD-22',
#    'party': 'Democrat',
#    'candidate': 'TERRY DENNIS',
#    'votes': 1376}],
#  [{'district': 'SD-24',
#    'party': 'Republican',
#    'candidate': 'ELIJAH TIDSWELL',
#    'votes': 2167}],
#  [{'district': 'SD-24',
#    'party': 'Democrat',
#    'candidate': 'KATHY KELKER',
#    'votes': 2243}],
#  [{'district': 'SD-27',
#    'party': 'Republican',
#    'candidate': 'DENNIS LENZ',
#    'votes': 5697}],
#  [{'district': 'SD-29',
#    'party': 'Republican',
#    'candidate': 'FORREST JAMES MANDEVILLE',
#    'votes': 4086}],
#  [{'district': 'SD-30',
#    'party': 'Republican',
#    'candidate': 'JOHN ESP',
#    'votes': 3559}],
#  [{'district': 'SD-30',
#    'party': 'Democrat',
#    'candidate': 'JAMIE L ISALY',
#    'votes': 1971}],
#  [{'district': 'SD-32',
#    'party': 'Republican',
#    'candidate': 'RANDY CHAMBERLIN',
#    'votes': 2242}],
#  [{'district': 'SD-32',
#    'party': 'Democrat',
#    'candidate': 'PAT FLOWERS',
#    'votes': 1993}],
#  [{'district': 'SD-33',
#    'party': 'Republican',
#    'candidate': 'ADAM DEWIS',
#    'votes': 1457}],
#  [{'district': 'SD-33',
#    'party': 'Democrat',
#    'candidate': 'DENISE HAYMAN',
#    'votes': 2986}],
#  [{'district': 'SD-34',
#    'party': 'Republican',
#    'candidate': 'SHELLEY VANCE',
#    'votes': 2292},
#   {'district': 'SD-34',
#    'party': 'Republican',
#    'candidate': 'BRYAN DONALD HAYSOM',
#    'votes': 949}],
#  [{'district': 'SD-34',
#    'party': 'Democrat',
#    'candidate': 'DAMION LYNN',
#    'votes': 1502}],
#  [{'district': 'SD-41',
#    'party': 'Republican',
#    'candidate': 'DAVE GALT',
#    'votes': 2195}],
#  [{'district': 'SD-41',
#    'party': 'Democrat',
#    'candidate': 'JANET ELLIS',
#    'votes': 3053}],
#  [{'district': 'SD-42',
#    'party': 'Republican',
#    'candidate': 'MATT OLSON',
#    'votes': 2072}],
#  [{'district': 'SD-42',
#    'party': 'Democrat',
#    'candidate': 'MARY ANN DUNWELL',
#    'votes': 2857}],
#  [{'district': 'SD-43',
#    'party': 'Republican',
#    'candidate': 'JASON W ELLSWORTH',
#    'votes': 3474},
#   {'district': 'SD-43',
#    'party': 'Republican',
#    'candidate': 'JOEDE VANEK',
#    'votes': 1643}],
#  [{'district': 'SD-43',
#    'party': 'Democrat',
#    'candidate': 'JOHN F SCHNEEBERGER',
#    'votes': 1515}],
#  [{'district': 'SD-48',
#    'party': 'Republican',
#    'candidate': 'JACOB VAN HORN',
#    'votes': 1581}],
#  [{'district': 'SD-48',
#    'party': 'Democrat',
#    'candidate': 'SHANE A. MORIGEAU',
#    'votes': 2948}],
#  [{'district': 'SD-49',
#    'party': 'Republican',
#    'candidate': 'BRAD TSCHIDA',
#    'votes': 2283},
#   {'district': 'SD-49',
#    'party': 'Republican',
#    'candidate': 'NANCY BURGOYNE',
#    'votes': 737}],
#  [{'district': 'SD-49',
#    'party': 'Democrat',
#    'candidate': 'WILLIS CURDY',
#    'votes': 2942}],
#  [{'district': 'SD-50',
#    'party': 'Republican',
#    'candidate': 'NICK KNOWLES',
#    'votes': 1306}],
#  [{'district': 'SD-50',
#    'party': 'Democrat',
#    'candidate': 'ANDREA OLSEN',
#    'votes': 2644},
#   {'district': 'SD-50',
#    'party': 'Democrat',
#    'candidate': 'TOM STEENBERG',
#    'votes': 1577}],
#  [{'district': 'HD-1',
#    'party': 'Republican',
#    'candidate': 'STEVE GUNDERSON',
#    'votes': 1688}],
#  [{'district': 'HD-2',
#    'party': 'Republican',
#    'candidate': 'NEIL A. DURAM',
#    'votes': 2217}],
#  [{'district': 'HD-3',
#    'party': 'Republican',
#    'candidate': 'BRAXTON MITCHELL',
#    'votes': 1348},
#   {'district': 'HD-3',
#    'party': 'Republican',
#    'candidate': 'LORENA WOOD',
#    'votes': 495}],
#  [{'district': 'HD-3',
#    'party': 'Democrat',
#    'candidate': 'ANDREA GETTS',
#    'votes': 564}],
#  [{'district': 'HD-4',
#    'party': 'Republican',
#    'candidate': 'MATT REGIER',
#    'votes': 2350}],
#  [{'district': 'HD-4',
#    'party': 'Democrat',
#    'candidate': 'KIMBERLY PINTER',
#    'votes': 471}],
#  [{'district': 'HD-5',
#    'party': 'Republican',
#    'candidate': 'LYN BENNETT',
#    'votes': 820},
#   {'district': 'HD-5',
#    'party': 'Republican',
#    'candidate': 'BRIAN OWENS',
#    'votes': 636}],
#  [{'district': 'HD-5',
#    'party': 'Democrat',
#    'candidate': 'DAVE FERN',
#    'votes': 1166}],
#  [{'district': 'HD-6',
#    'party': 'Republican',
#    'candidate': 'AMY REGIER',
#    'votes': 2375}],
#  [{'district': 'HD-7',
#    'party': 'Republican',
#    'candidate': 'DAVE INGRAM',
#    'votes': 685},
#   {'district': 'HD-7',
#    'party': 'Republican',
#    'candidate': 'COURTENAY SPRUNGER',
#    'votes': 811}],
#  [{'district': 'HD-7',
#    'party': 'Democrat',
#    'candidate': 'ANGELA KENNEDY',
#    'votes': 383}],
#  [{'district': 'HD-8',
#    'party': 'Republican',
#    'candidate': 'TERRY FALK',
#    'votes': 1138},
#   {'district': 'HD-8',
#    'party': 'Republican',
#    'candidate': 'MARK TWICHEL',
#    'votes': 393},
#   {'district': 'HD-8',
#    'party': 'Republican',
#    'candidate': 'DAVID DUNN',
#    'votes': 325},
#   {'district': 'HD-8',
#    'party': 'Republican',
#    'candidate': 'LYNNE M (OGDEN) RIDER',
#    'votes': 342}],
#  [{'district': 'HD-9',
#    'party': 'Republican',
#    'candidate': 'DAVID AUGUST',
#    'votes': 480},
#   {'district': 'HD-9',
#    'party': 'Republican',
#    'candidate': 'CONSTANCE NEUMANN',
#    'votes': 709},
#   {'district': 'HD-9',
#    'party': 'Republican',
#    'candidate': 'TONY BROCKMAN',
#    'votes': 769}],
#  [{'district': 'HD-10',
#    'party': 'Republican',
#    'candidate': 'BOB KEENAN',
#    'votes': 2539}],
#  [{'district': 'HD-10',
#    'party': 'Democrat',
#    'candidate': 'MARK H PHILLIPS',
#    'votes': 591}],
#  [{'district': 'HD-11',
#    'party': 'Republican',
#    'candidate': 'RONALEE SKEES',
#    'votes': 776},
#   {'district': 'HD-11',
#    'party': 'Republican',
#    'candidate': 'TANNER J SMITH',
#    'votes': 1545},
#   {'district': 'HD-11',
#    'party': 'Republican',
#    'candidate': 'DEVON DECKER',
#    'votes': 429}],
#  [{'district': 'HD-12',
#    'party': 'Republican',
#    'candidate': 'LINDA REKSTEN',
#    'votes': 1990}],
#  [{'district': 'HD-12',
#    'party': 'Democrat',
#    'candidate': 'STERLING JAMES LAUDON',
#    'votes': 855}],
#  [{'district': 'HD-13',
#    'party': 'Republican',
#    'candidate': 'PAUL C FIELDER',
#    'votes': 2644}],
#  [{'district': 'HD-13',
#    'party': 'Democrat',
#    'candidate': 'COLLEEN HINDS',
#    'votes': 666}],
#  [{'district': 'HD-14',
#    'party': 'Republican',
#    'candidate': 'DENLEY M LOGE',
#    'votes': 1914},
#   {'district': 'HD-14',
#    'party': 'Republican',
#    'candidate': 'RANDY D MITCHELL',
#    'votes': 985}],
#  [{'district': 'HD-15',
#    'party': 'Republican',
#    'candidate': 'BETHSAIDA (BETSY) JOHNSON',
#    'votes': 374},
#   {'district': 'HD-15',
#    'party': 'Republican',
#    'candidate': 'RALPH FOSTER',
#    'votes': 392}],
#  [{'district': 'HD-15',
#    'party': 'Democrat',
#    'candidate': 'ADRIEN OWEN WAGNER',
#    'votes': 150},
#   {'district': 'HD-15',
#    'party': 'Democrat',
#    'candidate': 'MARVIN R. WEATHERWAX JR',
#    'votes': 306},
#   {'district': 'HD-15',
#    'party': 'Democrat',
#    'candidate': 'THEDIS B CROWE',
#    'votes': 119}],
#  [{'district': 'HD-16',
#    'party': 'Democrat',
#    'candidate': 'TYSON RUNNING WOLF',
#    'votes': 944}],
#  [{'district': 'HD-17',
#    'party': 'Republican',
#    'candidate': 'JUSTIN CLEVELAND',
#    'votes': 1097},
#   {'district': 'HD-17',
#    'party': 'Republican',
#    'candidate': 'ROSS H FITZGERALD',
#    'votes': 1669}],
#  [{'district': 'HD-17',
#    'party': 'Democrat',
#    'candidate': 'BARNETT G. SPORKIN-MORRISON',
#    'votes': 455}],
#  [{'district': 'HD-18',
#    'party': 'Republican',
#    'candidate': 'LLEW JONES',
#    'votes': 1741}],
#  [{'district': 'HD-19',
#    'party': 'Republican',
#    'candidate': 'RUSSEL MINER',
#    'votes': 1842}],
#  [{'district': 'HD-20',
#    'party': 'Republican',
#    'candidate': 'FRED ANDERSON',
#    'votes': 2046}],
#  [{'district': 'HD-20',
#    'party': 'Democrat',
#    'candidate': 'SAMANTHA RISPENS',
#    'votes': 656}],
#  [{'district': 'HD-21',
#    'party': 'Republican',
#    'candidate': 'ED BUTTREY',
#    'votes': 1298}],
#  [{'district': 'HD-21',
#    'party': 'Democrat',
#    'candidate': 'LELA GRAHAM',
#    'votes': 620}],
#  [{'district': 'HD-22',
#    'party': 'Republican',
#    'candidate': 'LOLA SHELDON-GALLOWAY',
#    'votes': 1058}],
#  [{'district': 'HD-22',
#    'party': 'Democrat',
#    'candidate': 'NICK R. D. HENRY',
#    'votes': 530}],
#  [{'district': 'HD-22',
#    'party': 'Libertarian',
#    'candidate': 'TONY ROSALES',
#    'votes': 22}],
#  [{'district': 'HD-23',
#    'party': 'Republican',
#    'candidate': 'SCOT KERNS',
#    'votes': 843}],
#  [{'district': 'HD-23',
#    'party': 'Democrat',
#    'candidate': 'MELISSA SMITH',
#    'votes': 319},
#   {'district': 'HD-23',
#    'party': 'Democrat',
#    'candidate': 'BRAD HAMLETT',
#    'votes': 300}],
#  [{'district': 'HD-24',
#    'party': 'Republican',
#    'candidate': 'STEVEN GALLOWAY',
#    'votes': 1005}],
#  [{'district': 'HD-24',
#    'party': 'Democrat',
#    'candidate': 'BARBARA BESSETTE',
#    'votes': 608}],
#  [{'district': 'HD-25',
#    'party': 'Republican',
#    'candidate': 'STEVE GIST',
#    'votes': 994}],
#  [{'district': 'HD-25',
#    'party': 'Democrat',
#    'candidate': 'JASMINE KROTKOV',
#    'votes': 564}],
#  [{'district': 'HD-26',
#    'party': 'Republican',
#    'candidate': 'GEORGE NIKOLAKAKOS',
#    'votes': 438},
#   {'district': 'HD-26',
#    'party': 'Republican',
#    'candidate': 'MARCI MARCEAU',
#    'votes': 314}],
#  [{'district': 'HD-26',
#    'party': 'Democrat',
#    'candidate': 'KARI ROSENLEAF',
#    'votes': 379}],
#  [{'district': 'HD-27',
#    'party': 'Republican',
#    'candidate': 'JOSH KASSMIER',
#    'votes': 2413}],
#  [{'district': 'HD-28',
#    'party': 'Republican',
#    'candidate': 'ED HILL',
#    'votes': 826}],
#  [{'district': 'HD-28',
#    'party': 'Democrat',
#    'candidate': 'PAUL TUSS',
#    'votes': 755}],
#  [{'district': 'HD-29',
#    'party': 'Republican',
#    'candidate': 'DOUGLAS FLAMENT',
#    'votes': 2238}],
#  [{'district': 'HD-30',
#    'party': 'Republican',
#    'candidate': 'RANDYN GREGG',
#    'votes': 1312},
#   {'district': 'HD-30',
#    'party': 'Republican',
#    'candidate': 'JAMES H BERGSTROM',
#    'votes': 1507}],
#  [{'district': 'HD-30',
#    'party': 'Democrat',
#    'candidate': 'WENDY PALMER',
#    'votes': 355}],
#  [{'district': 'HD-31',
#    'party': 'Republican',
#    'candidate': 'ARLIE W GORDON',
#    'votes': 586}],
#  [{'district': 'HD-31',
#    'party': 'Democrat',
#    'candidate': 'FRANK J. SMITH',
#    'votes': 360},
#   {'district': 'HD-31',
#    'party': 'Democrat',
#    'candidate': 'KACI WALLETTE',
#    'votes': 273}],
#  [{'district': 'HD-32',
#    'party': 'Democrat',
#    'candidate': 'JONATHAN WINDY BOY',
#    'votes': 298}],
#  [{'district': 'HD-33',
#    'party': 'Republican',
#    'candidate': 'CASEY JAMES KNUDSEN',
#    'votes': 1864}],
#  [{'district': 'HD-33',
#    'party': 'Democrat',
#    'candidate': 'JORDAN OPHUS',
#    'votes': 388}],
#  [{'district': 'HD-34',
#    'party': 'Republican',
#    'candidate': 'RHONDA KNUDSEN',
#    'votes': 2076}],
#  [{'district': 'HD-35',
#    'party': 'Republican',
#    'candidate': 'BRANDON LER',
#    'votes': 1877}],
#  [{'district': 'HD-36',
#    'party': 'Republican',
#    'candidate': 'BOB PHALEN',
#    'votes': 1924}],
#  [{'district': 'HD-37',
#    'party': 'Republican',
#    'candidate': 'JERRY SCHILLINGER',
#    'votes': 3045}],
#  [{'district': 'HD-38',
#    'party': 'Republican',
#    'candidate': 'WYATT WINCHESTER ENGLISH',
#    'votes': 85},
#   {'district': 'HD-38',
#    'party': 'Republican',
#    'candidate': 'GREG KMETZ',
#    'votes': 1201},
#   {'district': 'HD-38',
#    'party': 'Republican',
#    'candidate': 'MIKE WILLEMS',
#    'votes': 559}],
#  [{'district': 'HD-38',
#    'party': 'Democrat',
#    'candidate': 'STEVE MUGGLI',
#    'votes': 579}],
#  [{'district': 'HD-39',
#    'party': 'Republican',
#    'candidate': 'GARY PARRY',
#    'votes': 2348}],
#  [{'district': 'HD-40',
#    'party': 'Republican',
#    'candidate': 'JOHN NICKELSON',
#    'votes': 603},
#   {'district': 'HD-40',
#    'party': 'Republican',
#    'candidate': 'BRUCE HOILAND',
#    'votes': 367},
#   {'district': 'HD-40',
#    'party': 'Republican',
#    'candidate': 'GREG OBLANDER',
#    'votes': 1109},
#   {'district': 'HD-40',
#    'party': 'Republican',
#    'candidate': 'ROBERT (BOB) T GOFFENA',
#    'votes': 602}],
#  [{'district': 'HD-41',
#    'party': 'Republican',
#    'candidate': 'PAUL GREEN',
#    'votes': 701}],
#  [{'district': 'HD-41',
#    'party': 'Democrat',
#    'candidate': 'RYNALEA WHITEMAN PENA',
#    'votes': 301}],
#  [{'district': 'HD-42',
#    'party': 'Republican',
#    'candidate': 'VIRGINIA MCDONALD',
#    'votes': 689}],
#  [{'district': 'HD-42',
#    'party': 'Democrat',
#    'candidate': 'SHARON STEWART PEREGOY',
#    'votes': 564}],
#  [{'district': 'HD-43',
#    'party': 'Republican',
#    'candidate': 'KERRI SEEKINS-CROWE',
#    'votes': 1692}],
#  [{'district': 'HD-44',
#    'party': 'Republican',
#    'candidate': 'LARRY BREWSTER',
#    'votes': 1591}],
#  [{'district': 'HD-44',
#    'party': 'Democrat',
#    'candidate': 'MELISSA SMITH',
#    'votes': 773}],
#  [{'district': 'HD-45',
#    'party': 'Republican',
#    'candidate': 'KATIE ZOLNIKOV',
#    'votes': 2034}],
#  [{'district': 'HD-46',
#    'party': 'Republican',
#    'candidate': 'BILL MERCER',
#    'votes': 2282}],
#  [{'district': 'HD-46',
#    'party': 'Democrat',
#    'candidate': 'TIM WARBURTON',
#    'votes': 1031}],
#  [{'district': 'HD-47',
#    'party': 'Republican',
#    'candidate': 'THOMAS J MADIGAN',
#    'votes': 935}],
#  [{'district': 'HD-47',
#    'party': 'Democrat',
#    'candidate': 'DENISE BAUM',
#    'votes': 989}],
#  [{'district': 'HD-48',
#    'party': 'Republican',
#    'candidate': 'JODEE ETCHART',
#    'votes': 1253}],
#  [{'district': 'HD-48',
#    'party': 'Democrat',
#    'candidate': 'JENNIFER MERECKI',
#    'votes': 1091}],
#  [{'district': 'HD-49',
#    'party': 'Republican',
#    'candidate': 'JEFF WYLIE',
#    'votes': 691}],
#  [{'district': 'HD-49',
#    'party': 'Democrat',
#    'candidate': 'EMMA KERR-CARPENTER',
#    'votes': 770}],
#  [{'district': 'HD-50',
#    'party': 'Republican',
#    'candidate': 'MALLERIE C STROMSWOLD',
#    'votes': 1028}],
#  [{'district': 'HD-50',
#    'party': 'Democrat',
#    'candidate': 'ERIN R. TATE',
#    'votes': 422},
#   {'district': 'HD-50',
#    'party': 'Democrat',
#    'candidate': 'JAMES REAVIS',
#    'votes': 458}],
#  [{'district': 'HD-51',
#    'party': 'Republican',
#    'candidate': 'MIKE YAKAWICH',
#    'votes': 1211}],
#  [{'district': 'HD-51',
#    'party': 'Democrat',
#    'candidate': 'CAROLE BOERNER',
#    'votes': 821}],
#  [{'district': 'HD-52',
#    'party': 'Republican',
#    'candidate': 'SHERRY ESSMAN',
#    'votes': 1237}],
#  [{'district': 'HD-52',
#    'party': 'Democrat',
#    'candidate': 'JENNA MARTIN',
#    'votes': 678}],
#  [{'district': 'HD-53',
#    'party': 'Republican',
#    'candidate': 'NELLY NICOL',
#    'votes': 3422}],
#  [{'district': 'HD-54',
#    'party': 'Republican',
#    'candidate': 'TERRY MOORE',
#    'votes': 2247}],
#  [{'district': 'HD-55',
#    'party': 'Republican',
#    'candidate': 'CURTIS SCHOMER',
#    'votes': 547},
#   {'district': 'HD-55',
#    'party': 'Republican',
#    'candidate': 'LEE DEMING',
#    'votes': 1413}],
#  [{'district': 'HD-56',
#    'party': 'Republican',
#    'candidate': 'SUE VINTON',
#    'votes': 1776}],
#  [{'district': 'HD-57',
#    'party': 'Republican',
#    'candidate': 'FIONA B NAVE',
#    'votes': 2052}],
#  [{'district': 'HD-57',
#    'party': 'Democrat',
#    'candidate': 'THOMAS E FLANAGAN',
#    'votes': 332}],
#  [{'district': 'HD-58',
#    'party': 'Republican',
#    'candidate': 'BRAD BARKER',
#    'votes': 1834}],
#  [{'district': 'HD-58',
#    'party': 'Democrat',
#    'candidate': 'JUDITH P GREGORY',
#    'votes': 951}],
#  [{'district': 'HD-59',
#    'party': 'Republican',
#    'candidate': 'MARTY MALONE',
#    'votes': 2290}],
#  [{'district': 'HD-59',
#    'party': 'Democrat',
#    'candidate': 'RUTH WEISSMAN',
#    'votes': 760}],
#  [{'district': 'HD-60',
#    'party': 'Republican',
#    'candidate': 'DAN SKATTUM',
#    'votes': 1141}],
#  [{'district': 'HD-60',
#    'party': 'Democrat',
#    'candidate': 'LAURIE BISHOP',
#    'votes': 1265}],
#  [{'district': 'HD-61',
#    'party': 'Republican',
#    'candidate': 'PETER BOWER',
#    'votes': 1334}],
#  [{'district': 'HD-61',
#    'party': 'Democrat',
#    'candidate': 'JIM HAMILTON',
#    'votes': 2124}],
#  [{'district': 'HD-62',
#    'party': 'Republican',
#    'candidate': 'MARC GREENDORFER',
#    'votes': 827}],
#  [{'district': 'HD-62',
#    'party': 'Democrat',
#    'candidate': 'ED STAFMAN',
#    'votes': 2151}],
#  [{'district': 'HD-63',
#    'party': 'Republican',
#    'candidate': 'CATHERINE PURCELL',
#    'votes': 594}],
#  [{'district': 'HD-63',
#    'party': 'Democrat',
#    'candidate': 'ALICE BUCKLEY',
#    'votes': 802}],
#  [{'district': 'HD-64',
#    'party': 'Republican',
#    'candidate': 'JANE GILLETTE',
#    'votes': 1654}],
#  [{'district': 'HD-64',
#    'party': 'Democrat',
#    'candidate': 'ALANAH GRIFFITH',
#    'votes': 905},
#   {'district': 'HD-64',
#    'party': 'Democrat',
#    'candidate': 'MICHELLE VERED',
#    'votes': 319}],
#  [{'district': 'HD-65',
#    'party': 'Republican',
#    'candidate': 'JAMES COCCO',
#    'votes': 724},
#   {'district': 'HD-65',
#    'party': 'Republican',
#    'candidate': 'RYAN EISELE',
#    'votes': 308}],
#  [{'district': 'HD-65',
#    'party': 'Democrat',
#    'candidate': 'KELLY KORTUM',
#    'votes': 1705}],
#  [{'district': 'HD-66',
#    'party': 'Democrat',
#    'candidate': 'ERIC MATTHEWS',
#    'votes': 1268}],
#  [{'district': 'HD-67',
#    'party': 'Republican',
#    'candidate': 'JEDEDIAH HINKLE',
#    'votes': 1422}],
#  [{'district': 'HD-67',
#    'party': 'Democrat',
#    'candidate': 'ELIZABETH MARUM',
#    'votes': 882}],
#  [{'district': 'HD-68',
#    'party': 'Republican',
#    'candidate': 'CALEB HINKLE',
#    'votes': 1295},
#   {'district': 'HD-68',
#    'party': 'Republican',
#    'candidate': 'BRUCE GRUBBS',
#    'votes': 507}],
#  [{'district': 'HD-68',
#    'party': 'Democrat',
#    'candidate': 'JOE HANCOCK',
#    'votes': 651}],
#  [{'district': 'HD-69',
#    'party': 'Republican',
#    'candidate': 'JENNIFER CARLSON',
#    'votes': 2171}],
#  [{'district': 'HD-69',
#    'party': 'Democrat',
#    'candidate': 'ROCKY HAMILTON',
#    'votes': 791}],
#  [{'district': 'HD-70',
#    'party': 'Republican',
#    'candidate': 'JULIE DOOLING',
#    'votes': 2346}],
#  [{'district': 'HD-70',
#    'party': 'Democrat',
#    'candidate': 'JEREMIAH DAWSON',
#    'votes': 391},
#   {'district': 'HD-70',
#    'party': 'Democrat',
#    'candidate': 'JON JACKSON',
#    'votes': 408}],
#  [{'district': 'HD-71',
#    'party': 'Republican',
#    'candidate': 'KEN WALSH',
#    'votes': 2502}],
#  [{'district': 'HD-72',
#    'party': 'Republican',
#    'candidate': 'TOM WELCH',
#    'votes': 2160}],
#  [{'district': 'HD-72',
#    'party': 'Democrat',
#    'candidate': 'HOLT GIBSON',
#    'votes': 462}],
#  [{'district': 'HD-73',
#    'party': 'Republican',
#    'candidate': 'JASON FREEMAN',
#    'votes': 654}],
#  [{'district': 'HD-73',
#    'party': 'Democrat',
#    'candidate': 'ART NOONAN',
#    'votes': 1404}],
#  [{'district': 'HD-74',
#    'party': 'Republican',
#    'candidate': 'JAMES W KEPHART',
#    'votes': 426}],
#  [{'district': 'HD-74',
#    'party': 'Democrat',
#    'candidate': 'DEREK J HARVEY',
#    'votes': 1157}],
#  [{'district': 'HD-75',
#    'party': 'Republican',
#    'candidate': 'MARTA BERTOGLIO',
#    'votes': 1715},
#   {'district': 'HD-75',
#    'party': 'Republican',
#    'candidate': 'TIMOTHY D MCKENRICK',
#    'votes': 645}],
#  [{'district': 'HD-76',
#    'party': 'Republican',
#    'candidate': 'SUZZANN NORDWICK',
#    'votes': 926}],
#  [{'district': 'HD-76',
#    'party': 'Democrat',
#    'candidate': 'DONAVON HAWK',
#    'votes': 1878}],
#  [{'district': 'HD-77',
#    'party': 'Republican',
#    'candidate': 'JOHN FITZPATRICK',
#    'votes': 1518}],
#  [{'district': 'HD-77',
#    'party': 'Democrat',
#    'candidate': 'SARA NOVAK',
#    'votes': 1546}],
#  [{'district': 'HD-78',
#    'party': 'Republican',
#    'candidate': 'GREGORY LEE FRAZER',
#    'votes': 662},
#   {'district': 'HD-78',
#    'party': 'Republican',
#    'candidate': 'STEVEN D GRANT',
#    'votes': 496}],
#  [{'district': 'HD-79',
#    'party': 'Republican',
#    'candidate': 'DENNISON RIVERA',
#    'votes': 1048}],
#  [{'district': 'HD-79',
#    'party': 'Democrat',
#    'candidate': 'LAURA SMITH',
#    'votes': 1776}],
#  [{'district': 'HD-80',
#    'party': 'Republican',
#    'candidate': 'BECKY BEARD',
#    'votes': 2151}],
#  [{'district': 'HD-81',
#    'party': 'Republican',
#    'candidate': 'CHARLIE HULL',
#    'votes': 485},
#   {'district': 'HD-81',
#    'party': 'Republican',
#    'candidate': 'JILL SARK',
#    'votes': 643}],
#  [{'district': 'HD-81',
#    'party': 'Democrat',
#    'candidate': 'JAKE C TROYER',
#    'votes': 313},
#   {'district': 'HD-81',
#    'party': 'Democrat',
#    'candidate': 'JACOB B. TORGERSON',
#    'votes': 263},
#   {'district': 'HD-81',
#    'party': 'Democrat',
#    'candidate': 'MELISSA ROMANO',
#    'votes': 1108}],
#  [{'district': 'HD-82',
#    'party': 'Republican',
#    'candidate': 'ALDEN TONKAY',
#    'votes': 1064}],
#  [{'district': 'HD-82',
#    'party': 'Democrat',
#    'candidate': 'MARY CAFERRO',
#    'votes': 1379},
#   {'district': 'HD-82',
#    'party': 'Democrat',
#    'candidate': 'CRAIG SUNDBERG',
#    'votes': 178}],
#  [{'district': 'HD-83',
#    'party': 'Republican',
#    'candidate': 'BOB LEACH',
#    'votes': 886}],
#  [{'district': 'HD-83',
#    'party': 'Democrat',
#    'candidate': 'KIM ABBOTT',
#    'votes': 1402}],
#  [{'district': 'HD-84',
#    'party': 'Republican',
#    'candidate': 'KURT J AUGHNEY',
#    'votes': 364},
#   {'district': 'HD-84',
#    'party': 'Republican',
#    'candidate': 'KAITLYN RUCH',
#    'votes': 509},
#   {'district': 'HD-84',
#    'party': 'Republican',
#    'candidate': 'KEITH PIGMAN',
#    'votes': 406}],
#  [{'district': 'HD-84',
#    'party': 'Democrat',
#    'candidate': 'JILL COHENOUR',
#    'votes': 1331},
#   {'district': 'HD-84',
#    'party': 'Democrat',
#    'candidate': 'NOAH J HORAN',
#    'votes': 112}],
#  [{'district': 'HD-85',
#    'party': 'Republican',
#    'candidate': 'MICHELE BINKLEY',
#    'votes': 2473}],
#  [{'district': 'HD-85',
#    'party': 'Democrat',
#    'candidate': 'ROSAN STOVER',
#    'votes': 661}],
#  [{'district': 'HD-86',
#    'party': 'Republican',
#    'candidate': 'DAVID BEDEY',
#    'votes': 1914},
#   {'district': 'HD-86',
#    'party': 'Republican',
#    'candidate': 'JEFFREY B JONES',
#    'votes': 413}],
#  [{'district': 'HD-86',
#    'party': 'Democrat',
#    'candidate': 'ANNE W BROWN',
#    'votes': 783}],
#  [{'district': 'HD-87',
#    'party': 'Republican',
#    'candidate': 'RON MARSHALL',
#    'votes': 2116}],
#  [{'district': 'HD-88',
#    'party': 'Republican',
#    'candidate': 'ALAN LACKEY',
#    'votes': 1050},
#   {'district': 'HD-88',
#    'party': 'Republican',
#    'candidate': 'WAYNE RUSK',
#    'votes': 1541}],
#  [{'district': 'HD-88',
#    'party': 'Democrat',
#    'candidate': 'KO MOUA',
#    'votes': 699}],
#  [{'district': 'HD-89',
#    'party': 'Republican',
#    'candidate': 'GARY WANBERG',
#    'votes': 812}],
#  [{'district': 'HD-89',
#    'party': 'Democrat',
#    'candidate': 'KATIE SULLIVAN',
#    'votes': 1427}],
#  [{'district': 'HD-90',
#    'party': 'Republican',
#    'candidate': 'ALAN AULT',
#    'votes': 719}],
#  [{'district': 'HD-90',
#    'party': 'Democrat',
#    'candidate': 'MARILYN MARLER',
#    'votes': 1724}],
#  [{'district': 'HD-91',
#    'party': 'Republican',
#    'candidate': 'ANTHONY PAWLISZ',
#    'votes': 406}],
#  [{'district': 'HD-91',
#    'party': 'Democrat',
#    'candidate': 'CONNIE KEOGH',
#    'votes': 2584}],
#  [{'district': 'HD-92',
#    'party': 'Republican',
#    'candidate': 'MIKE HOPKINS',
#    'votes': 1322}],
#  [{'district': 'HD-92',
#    'party': 'Democrat',
#    'candidate': 'GARY M. STEIN',
#    'votes': 1056}],
#  [{'district': 'HD-93',
#    'party': 'Republican',
#    'candidate': 'JOE READ',
#    'votes': 1504}],
#  [{'district': 'HD-93',
#    'party': 'Democrat',
#    'candidate': 'SHIRLEY AZZOPARDI',
#    'votes': 640}],
#  [{'district': 'HD-94',
#    'party': 'Republican',
#    'candidate': 'REBECCA MAPSTON',
#    'votes': 983}],
#  [{'district': 'HD-94',
#    'party': 'Democrat',
#    'candidate': 'TOM FRANCE',
#    'votes': 1410}],
#  [{'district': 'HD-95',
#    'party': 'Republican',
#    'candidate': 'LAUREN SUBITH',
#    'votes': 388}],
#  [{'district': 'HD-95',
#    'party': 'Democrat',
#    'candidate': 'SJ HOWELL',
#    'votes': 1460}],
#  [{'district': 'HD-96',
#    'party': 'Republican',
#    'candidate': 'KATHY WHITMAN',
#    'votes': 1166}],
#  [{'district': 'HD-96',
#    'party': 'Democrat',
#    'candidate': 'JONATHAN KARLEN',
#    'votes': 985},
#   {'district': 'HD-96',
#    'party': 'Democrat',
#    'candidate': 'LINDA SWANSON',
#    'votes': 494}],
#  [{'district': 'HD-97',
#    'party': 'Republican',
#    'candidate': 'MICHAEL BURKS',
#    'votes': 851},
#   {'district': 'HD-97',
#    'party': 'Republican',
#    'candidate': 'LYN HELLEGAARD',
#    'votes': 891}],
#  [{'district': 'HD-97',
#    'party': 'Democrat',
#    'candidate': 'DEVIN JACKSON',
#    'votes': 1181}],
#  [{'district': 'HD-98',
#    'party': 'Republican',
#    'candidate': 'SONIA SHEARER-HIETT',
#    'votes': 983}],
#  [{'district': 'HD-98',
#    'party': 'Democrat',
#    'candidate': 'BOB CARTER',
#    'votes': 994},
#   {'district': 'HD-98',
#    'party': 'Democrat',
#    'candidate': 'ANDY NELSON',
#    'votes': 738}],
#  [{'district': 'HD-99',
#    'party': 'Republican',
#    'candidate': 'RYAN DARLING',
#    'votes': 966}],
#  [{'district': 'HD-99',
#    'party': 'Democrat',
#    'candidate': 'MARK THANE',
#    'votes': 1786}],
#  [{'district': 'HD-100',
#    'party': 'Republican',
#    'candidate': 'SEAN PATRICK MCCOY',
#    'votes': 335}],
#  [{'district': 'HD-100',
#    'party': 'Democrat',
#    'candidate': 'DAVID SEVERSON',
#    'votes': 934},
#   {'district': 'HD-100',
#    'party': 'Democrat',
#    'candidate': 'ZOOEY ZEPHYR',
#    'votes': 1483}]]

# %%
tall = pd.DataFrame([item for district in output for item in district])
tall
# Out:
#     district       party           candidate  votes
# 0       SD-1  Republican     MICHAEL J CUFFE   3973
# 1       SD-4  Republican         JOHN FULLER   2082
# 2       SD-4  Republican         LEE HUESTIS   1590
# 3       SD-4    Democrat       KYLE WATERMAN    844
# 4       SD-5  Republican         MARK NOLAND   2967
# ..       ...         ...                 ...    ...
# 264    HD-99  Republican        RYAN DARLING    966
# 265    HD-99    Democrat          MARK THANE   1786
# 266   HD-100  Republican  SEAN PATRICK MCCOY    335
# 267   HD-100    Democrat      DAVID SEVERSON    934
# 268   HD-100    Democrat        ZOOEY ZEPHYR   1483
#
# [269 rows x 4 columns]

# %%
# Output for Capitol Tracker district input
tall.to_csv('./outputs/2022/primary/2022-primary-legislative-vote-counts.csv', index=False)
