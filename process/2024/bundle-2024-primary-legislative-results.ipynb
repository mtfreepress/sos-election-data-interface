# %%
# Bundles 2024 primary results for display in 2024 MTFP election guide
import pandas as pd

# %%
xl = pd.ExcelFile('./inputs/sos-data/2024/primary/2024_06_11_Legislative Results.xlsx')
sheets = xl.sheet_names

output = []
for sheet in sheets:
    dfi = xl.parse(sheet)
    reporting = dfi.iloc[:,0][1]
    time = dfi.iloc[:,0][2]
    district = dfi.iloc[:,0][5].replace('STATE SENATOR','S').replace('STATE REPRESENTATIVE','H').replace(' DISTRICT','D').replace(' ','-')

    data = dfi[5:].drop(dfi.columns[0], axis='columns').transpose()
    data.columns = data.iloc[0]
    data.drop(data.index[0], inplace=True)
    data.reset_index(inplace=True)
    output.append(list(data.apply(lambda row: ({
        'district': district,
        'party': row['County'].split('\n')[1],
        'candidate': row['County'].split('\n')[0],
        'votes': row['TOTALS'],
    }), axis=1)))
    
output
# Out:
# [[{'district': 'SD-2',
#    'party': 'Republican',
#    'candidate': 'DOUG ADAMS',
#    'votes': 2318}],
#  [{'district': 'SD-2',
#    'party': 'Democrat',
#    'candidate': 'DAVE FERN',
#    'votes': 2344}],
#  [{'district': 'SD-3',
#    'party': 'Republican',
#    'candidate': 'CARL GLIMM',
#    'votes': 3802}],
#  [{'district': 'SD-3',
#    'party': 'Democrat',
#    'candidate': 'ANGELA KENNEDY',
#    'votes': 1394}],
#  [{'district': 'SD-5',
#    'party': 'Republican',
#    'candidate': 'MARQUIS L LAUDE',
#    'votes': 1427},
#   {'district': 'SD-5',
#    'party': 'Republican',
#    'candidate': 'MATT REGIER',
#    'votes': 2890}],
#  [{'district': 'SD-5',
#    'party': 'Democrat',
#    'candidate': 'LINK NEIMARK',
#    'votes': 1015}],
#  [{'district': 'SD-7',
#    'party': 'Republican',
#    'candidate': 'GREG HERTZ',
#    'votes': 4409}],
#  [{'district': 'SD-7',
#    'party': 'Democrat',
#    'candidate': 'CRAIG PABLO',
#    'votes': 1573}],
#  [{'district': 'SD-13',
#    'party': 'Republican',
#    'candidate': 'JOSH KASSMIER',
#    'votes': 3321},
#   {'district': 'SD-13',
#    'party': 'Republican',
#    'candidate': 'LOLA SHELDON-GALLOWAY',
#    'votes': 1832}],
#  [{'district': 'SD-15',
#    'party': 'Republican',
#    'candidate': 'RHONDA KNUDSEN',
#    'votes': 1776},
#   {'district': 'SD-15',
#    'party': 'Republican',
#    'candidate': 'GREGG HUNTER',
#    'votes': 2918}],
#  [{'district': 'SD-16',
#    'party': 'Republican',
#    'candidate': 'PERRI A JACOBS',
#    'votes': 1305}],
#  [{'district': 'SD-16',
#    'party': 'Democrat',
#    'candidate': 'JONATHAN WINDY BOY',
#    'votes': 667},
#   {'district': 'SD-16',
#    'party': 'Democrat',
#    'candidate': 'BRIDGET SMITH',
#    'votes': 310}],
#  [{'district': 'SD-17',
#    'party': 'Republican',
#    'candidate': 'MIKE NEWTON',
#    'votes': 2418},
#   {'district': 'SD-17',
#    'party': 'Republican',
#    'candidate': 'BOB PHALEN',
#    'votes': 3634}],
#  [{'district': 'SD-20',
#    'party': 'Republican',
#    'candidate': 'SUE VINTON',
#    'votes': 3239}],
#  [{'district': 'SD-20',
#    'party': 'Democrat',
#    'candidate': 'LINDA AUCH',
#    'votes': 1098}],
#  [{'district': 'SD-21',
#    'party': 'Republican',
#    'candidate': 'GAYLE GEORGE LAMMERS',
#    'votes': 1417}],
#  [{'district': 'SD-21',
#    'party': 'Democrat',
#    'candidate': 'RAE PEPPERS',
#    'votes': 352},
#   {'district': 'SD-21',
#    'party': 'Democrat',
#    'candidate': 'SHARON STEWART PEREGOY',
#    'votes': 554}],
#  [{'district': 'SD-24',
#    'party': 'Republican',
#    'candidate': 'MIKE YAKAWICH',
#    'votes': 1736}],
#  [{'district': 'SD-24',
#    'party': 'Democrat',
#    'candidate': 'MARK H NICHOLSON',
#    'votes': 1272}],
#  [{'district': 'SD-26',
#    'party': 'Republican',
#    'candidate': 'TOM MCGILLVRAY',
#    'votes': 3921}],
#  [{'district': 'SD-26',
#    'party': 'Democrat',
#    'candidate': 'KAREN LYNCOLN',
#    'votes': 1793}],
#  [{'district': 'SD-27',
#    'party': 'Republican',
#    'candidate': 'CHRIS FRIEDEL',
#    'votes': 1640},
#   {'district': 'SD-27',
#    'party': 'Republican',
#    'candidate': 'VINCE RICCI',
#    'votes': 2519}],
#  [{'district': 'SD-27',
#    'party': 'Democrat',
#    'candidate': 'KATHLEEN GILLULY',
#    'votes': 1155}],
#  [{'district': 'SD-30',
#    'party': 'Republican',
#    'candidate': 'TYLER ROGERS',
#    'votes': 2050}],
#  [{'district': 'SD-30',
#    'party': 'Democrat',
#    'candidate': 'CORA NEUMANN',
#    'votes': 3009}],
#  [{'district': 'SD-33',
#    'party': 'Republican',
#    'candidate': 'NEAL GANSER',
#    'votes': 2198}],
#  [{'district': 'SD-33',
#    'party': 'Democrat',
#    'candidate': 'CHRISTOPHER POPE',
#    'votes': 2833}],
#  [{'district': 'SD-35',
#    'party': 'Republican',
#    'candidate': 'MARK (MJ) MCGINLEY',
#    'votes': 1251},
#   {'district': 'SD-35',
#    'party': 'Republican',
#    'candidate': 'TONY TEZAK',
#    'votes': 2256},
#   {'district': 'SD-35',
#    'party': 'Republican',
#    'candidate': 'RAY SHAW',
#    'votes': 2217}],
#  [{'district': 'SD-36',
#    'party': 'Republican',
#    'candidate': 'DARLEAN NEWMAN',
#    'votes': 1947}],
#  [{'district': 'SD-36',
#    'party': 'Democrat',
#    'candidate': 'JESSICA WICKS',
#    'votes': 1385},
#   {'district': 'SD-36',
#    'party': 'Democrat',
#    'candidate': 'SARA NOVAK',
#    'votes': 2412}],
#  [{'district': 'SD-37',
#    'party': 'Republican',
#    'candidate': 'JIM KEPHART',
#    'votes': 2016}],
#  [{'district': 'SD-37',
#    'party': 'Democrat',
#    'candidate': 'DEREK J HARVEY',
#    'votes': 3657}],
#  [{'district': 'SD-38',
#    'party': 'Republican',
#    'candidate': 'BECKY BEARD',
#    'votes': 2553},
#   {'district': 'SD-38',
#    'party': 'Republican',
#    'candidate': 'JEREMY MYGLAND',
#    'votes': 1357},
#   {'district': 'SD-38',
#    'party': 'Republican',
#    'candidate': 'GREGORY FRAZER',
#    'votes': 1378}],
#  [{'district': 'SD-38',
#    'party': 'Democrat',
#    'candidate': 'JEFFREY BENSON',
#    'votes': 1811}],
#  [{'district': 'SD-39',
#    'party': 'Republican',
#    'candidate': 'E WYLIE GALT',
#    'votes': 5089}],
#  [{'district': 'SD-39',
#    'party': 'Democrat',
#    'candidate': 'BRUCE SHULTZ',
#    'votes': 1079}],
#  [{'district': 'SD-40',
#    'party': 'Republican',
#    'candidate': 'GREG L GUTHRIE',
#    'votes': 2631}],
#  [{'district': 'SD-40',
#    'party': 'Democrat',
#    'candidate': 'LAURA SMITH',
#    'votes': 3249}],
#  [{'district': 'SD-44',
#    'party': 'Republican',
#    'candidate': 'WAYNE RUSK',
#    'votes': 2633},
#   {'district': 'SD-44',
#    'party': 'Republican',
#    'candidate': 'THERESA MANZELLA',
#    'votes': 3044},
#   {'district': 'SD-44',
#    'party': 'Republican',
#    'candidate': 'BRAD DAVIS',
#    'votes': 491}],
#  [{'district': 'SD-44',
#    'party': 'Democrat',
#    'candidate': 'CADE SCATOLINI',
#    'votes': 1337}],
#  [{'district': 'SD-45',
#    'party': 'Republican',
#    'candidate': 'DENLEY M LOGE',
#    'votes': 2952},
#   {'district': 'SD-45',
#    'party': 'Republican',
#    'candidate': 'ANNAMARIE WHITE',
#    'votes': 1218}],
#  [{'district': 'SD-45',
#    'party': 'Democrat',
#    'candidate': 'DEVIN JACKSON',
#    'votes': 2031}],
#  [{'district': 'SD-46',
#    'party': 'Republican',
#    'candidate': 'CHARLES HEADLEY',
#    'votes': 2197}],
#  [{'district': 'SD-46',
#    'party': 'Democrat',
#    'candidate': 'C B PEARSON',
#    'votes': 1507},
#   {'district': 'SD-46',
#    'party': 'Democrat',
#    'candidate': 'JACINDA MORIGEAU',
#    'votes': 1769}],
#  [{'district': 'SD-47',
#    'party': 'Republican',
#    'candidate': 'ABIGAIL MAKI',
#    'votes': 1495},
#   {'district': 'SD-47',
#    'party': 'Republican',
#    'candidate': 'ERICA SIATE',
#    'votes': 720}],
#  [{'district': 'SD-47',
#    'party': 'Democrat',
#    'candidate': 'ELLIE HILL BOLDMAN',
#    'votes': 3507}],
#  [{'district': 'HD-1',
#    'party': 'Republican',
#    'candidate': 'NEIL DURAM',
#    'votes': 2693}],
#  [{'district': 'HD-1',
#    'party': 'Democrat',
#    'candidate': 'DAKOTA V ADAMS',
#    'votes': 648}],
#  [{'district': 'HD-2',
#    'party': 'Republican',
#    'candidate': 'TOM MILLETT',
#    'votes': 1283},
#   {'district': 'HD-2',
#    'party': 'Republican',
#    'candidate': 'THOMAS JENKINS',
#    'votes': 963}],
#  [{'district': 'HD-2',
#    'party': 'Democrat',
#    'candidate': 'ELIZABETH STORY',
#    'votes': 544}],
#  [{'district': 'HD-3',
#    'party': 'Republican',
#    'candidate': 'CATHY MITCHELL',
#    'votes': 1208}],
#  [{'district': 'HD-3',
#    'party': 'Democrat',
#    'candidate': 'DEBO POWERS',
#    'votes': 1005},
#   {'district': 'HD-3',
#    'party': 'Democrat',
#    'candidate': 'GUTHRIE QUIST',
#    'votes': 367}],
#  [{'district': 'HD-4',
#    'party': 'Republican',
#    'candidate': 'LYN BENNETT',
#    'votes': 1143}],
#  [{'district': 'HD-4',
#    'party': 'Democrat',
#    'candidate': 'LINDSEY JORDAN',
#    'votes': 900}],
#  [{'district': 'HD-5',
#    'party': 'Republican',
#    'candidate': 'BRAXTON MITCHELL',
#    'votes': 1887}],
#  [{'district': 'HD-5',
#    'party': 'Democrat',
#    'candidate': 'STEVE PAUGH',
#    'votes': 577}],
#  [{'district': 'HD-6',
#    'party': 'Republican',
#    'candidate': 'AMY REGIER',
#    'votes': 2013}],
#  [{'district': 'HD-6',
#    'party': 'Democrat',
#    'candidate': 'VELVET PHILLIPSSULLIVAN',
#    'votes': 794}],
#  [{'district': 'HD-7',
#    'party': 'Republican',
#    'candidate': 'COURTENAY SPRUNGER',
#    'votes': 854},
#   {'district': 'HD-7',
#    'party': 'Republican',
#    'candidate': 'SHAUN PANDINA',
#    'votes': 507}],
#  [{'district': 'HD-7',
#    'party': 'Democrat',
#    'candidate': 'ARTHUR FRETHEIM',
#    'votes': 573}],
#  [{'district': 'HD-8',
#    'party': 'Republican',
#    'candidate': 'LUKAS SCHUBERT',
#    'votes': 1516},
#   {'district': 'HD-8',
#    'party': 'Republican',
#    'candidate': 'TONY BROCKMAN',
#    'votes': 1027}],
#  [{'district': 'HD-8',
#    'party': 'Democrat',
#    'candidate': 'BETH SIBERT',
#    'votes': 529}],
#  [{'district': 'HD-9',
#    'party': 'Republican',
#    'candidate': 'LEE HUESTIS',
#    'votes': 993},
#   {'district': 'HD-9',
#    'party': 'Republican',
#    'candidate': 'STEVEN C KELLY',
#    'votes': 1235}],
#  [{'district': 'HD-9',
#    'party': 'Democrat',
#    'candidate': 'JOANNE MORROW',
#    'votes': 575}],
#  [{'district': 'HD-10',
#    'party': 'Republican',
#    'candidate': 'TERRY FALK',
#    'votes': 1703}],
#  [{'district': 'HD-10',
#    'party': 'Democrat',
#    'candidate': 'DEVIN T MARCONI',
#    'votes': 445}],
#  [{'district': 'HD-11',
#    'party': 'Republican',
#    'candidate': 'ROB TRACY',
#    'votes': 970},
#   {'district': 'HD-11',
#    'party': 'Republican',
#    'candidate': 'ED BYRNE',
#    'votes': 1650}],
#  [{'district': 'HD-11',
#    'party': 'Democrat',
#    'candidate': 'JENNIFER ALLEN',
#    'votes': 644}],
#  [{'district': 'HD-12',
#    'party': 'Republican',
#    'candidate': 'TRACY A SHARP',
#    'votes': 2177}],
#  [{'district': 'HD-12',
#    'party': 'Democrat',
#    'candidate': 'BARRY OLSON',
#    'votes': 913}],
#  [{'district': 'HD-13',
#    'party': 'Republican',
#    'candidate': 'LINDA E REKSTEN',
#    'votes': 1908}],
#  [{'district': 'HD-13',
#    'party': 'Democrat',
#    'candidate': 'SHIRLEY AZZOPARDI',
#    'votes': 900}],
#  [{'district': 'HD-14',
#    'party': 'Republican',
#    'candidate': 'PAUL C FIELDER',
#    'votes': 2449}],
#  [{'district': 'HD-14',
#    'party': 'Democrat',
#    'candidate': 'COLLEEN HINDS',
#    'votes': 728}],
#  [{'district': 'HD-15',
#    'party': 'Republican',
#    'candidate': 'RALPH FOSTER',
#    'votes': 718}],
#  [{'district': 'HD-15',
#    'party': 'Democrat',
#    'candidate': 'THEDIS CROWE',
#    'votes': 705}],
#  [{'district': 'HD-16',
#    'party': 'Republican',
#    'candidate': 'ROLLAND ELY HEAGY',
#    'votes': 249},
#   {'district': 'HD-16',
#    'party': 'Republican',
#    'candidate': 'ELAINE UTTERBACK  MITCHELL',
#    'votes': 594}],
#  [{'district': 'HD-16',
#    'party': 'Democrat',
#    'candidate': 'TYSON T RUNNING WOLF',
#    'votes': 760}],
#  [{'district': 'HD-17',
#    'party': 'Republican',
#    'candidate': 'ZACK WIRTH',
#    'votes': 2245}],
#  [{'district': 'HD-17',
#    'party': 'Democrat',
#    'candidate': 'LEONARD BATES',
#    'votes': 780}],
#  [{'district': 'HD-18',
#    'party': 'Republican',
#    'candidate': 'LLEW JONES',
#    'votes': 1911},
#   {'district': 'HD-18',
#    'party': 'Republican',
#    'candidate': 'JAMES COOMBS',
#    'votes': 774}],
#  [{'district': 'HD-18',
#    'party': 'Democrat',
#    'candidate': 'DAVID ARENDS',
#    'votes': 570}],
#  [{'district': 'HD-19',
#    'party': 'Republican',
#    'candidate': 'HANNAH TREBAS',
#    'votes': 432},
#   {'district': 'HD-19',
#    'party': 'Republican',
#    'candidate': 'DERREN AUGER',
#    'votes': 261}],
#  [{'district': 'HD-19',
#    'party': 'Democrat',
#    'candidate': 'JANE WEBER',
#    'votes': 620}],
#  [{'district': 'HD-20',
#    'party': 'Republican',
#    'candidate': 'STEVEN GALLOWAY',
#    'votes': 729},
#   {'district': 'HD-20',
#    'party': 'Republican',
#    'candidate': 'MELISSA NIKOLAKAKOS',
#    'votes': 766}],
#  [{'district': 'HD-20',
#    'party': 'Democrat',
#    'candidate': 'RINA FONTANA MOORE',
#    'votes': 1022}],
#  [{'district': 'HD-21',
#    'party': 'Republican',
#    'candidate': 'ED BUTTREY',
#    'votes': 1326},
#   {'district': 'HD-21',
#    'party': 'Republican',
#    'candidate': 'JAMES OSTERMAN',
#    'votes': 500}],
#  [{'district': 'HD-21',
#    'party': 'Democrat',
#    'candidate': 'LELA GRAHAM',
#    'votes': 955}],
#  [{'district': 'HD-22',
#    'party': 'Republican',
#    'candidate': 'GEORGE NIKOLAKAKOS',
#    'votes': 680},
#   {'district': 'HD-22',
#    'party': 'Republican',
#    'candidate': 'JAMES G WHITAKER',
#    'votes': 267}],
#  [{'district': 'HD-22',
#    'party': 'Democrat',
#    'candidate': 'RONALD K PAULICK',
#    'votes': 541}],
#  [{'district': 'HD-23',
#    'party': 'Republican',
#    'candidate': 'ERIC TILLEMAN',
#    'votes': 820},
#   {'district': 'HD-23',
#    'party': 'Republican',
#    'candidate': 'PETE ANDERSON',
#    'votes': 293},
#   {'district': 'HD-23',
#    'party': 'Republican',
#    'candidate': 'JOHN H  PROUD',
#    'votes': 184},
#   {'district': 'HD-23',
#    'party': 'Republican',
#    'candidate': 'JOSH DENULLY',
#    'votes': 48}],
#  [{'district': 'HD-23',
#    'party': 'Democrat',
#    'candidate': 'SANDOR R HOPKINS',
#    'votes': 837}],
#  [{'district': 'HD-24',
#    'party': 'Republican',
#    'candidate': 'STEVE FITZPATRICK',
#    'votes': 1493}],
#  [{'district': 'HD-25',
#    'party': 'Republican',
#    'candidate': 'STEVE GIST',
#    'votes': 1842}],
#  [{'district': 'HD-25',
#    'party': 'Democrat',
#    'candidate': 'JAMES RICKLEY',
#    'votes': 541}],
#  [{'district': 'HD-26',
#    'party': 'Republican',
#    'candidate': 'RUSSEL MINER',
#    'votes': 1447},
#   {'district': 'HD-26',
#    'party': 'Republican',
#    'candidate': 'DANA  DARLINGTON',
#    'votes': 1293}],
#  [{'district': 'HD-27',
#    'party': 'Republican',
#    'candidate': 'ED HILL',
#    'votes': 999}],
#  [{'district': 'HD-27',
#    'party': 'Democrat',
#    'candidate': 'PAUL TUSS',
#    'votes': 865}],
#  [{'district': 'HD-28',
#    'party': 'Republican',
#    'candidate': 'ERIC ALBUS',
#    'votes': 1119},
#   {'district': 'HD-28',
#    'party': 'Republican',
#    'candidate': 'MARK L WICKS',
#    'votes': 914},
#   {'district': 'HD-28',
#    'party': 'Republican',
#    'candidate': 'WAYNE STAHL',
#    'votes': 722}],
#  [{'district': 'HD-28',
#    'party': 'Democrat',
#    'candidate': 'BLAKE BORST',
#    'votes': 481}],
#  [{'district': 'HD-29',
#    'party': 'Republican',
#    'candidate': 'MILES KNUDSEN  ',
#    'votes': 918},
#   {'district': 'HD-29',
#    'party': 'Republican',
#    'candidate': 'VALERIE MOORE',
#    'votes': 2019}],
#  [{'district': 'HD-30',
#    'party': 'Republican',
#    'candidate': 'MORGAN THIEL',
#    'votes': 1500}],
#  [{'district': 'HD-31',
#    'party': 'Republican',
#    'candidate': 'KEVIN TAYLOR',
#    'votes': 632}],
#  [{'district': 'HD-31',
#    'party': 'Democrat',
#    'candidate': 'LANCE FOURSTAR',
#    'votes': 201},
#   {'district': 'HD-31',
#    'party': 'Democrat',
#    'candidate': 'FRANK J SMITH',
#    'votes': 315}],
#  [{'district': 'HD-32',
#    'party': 'Republican',
#    'candidate': 'JASON ULRICH',
#    'votes': 708}],
#  [{'district': 'HD-32',
#    'party': 'Democrat',
#    'candidate': 'MIKE FOX',
#    'votes': 413}],
#  [{'district': 'HD-33',
#    'party': 'Republican',
#    'candidate': 'BRANDON LER',
#    'votes': 1586},
#   {'district': 'HD-33',
#    'party': 'Republican',
#    'candidate': 'KATHY HOILAND',
#    'votes': 926}],
#  [{'district': 'HD-34',
#    'party': 'Republican',
#    'candidate': 'JERRY SCHILLINGER',
#    'votes': 3270}],
#  [{'district': 'HD-35',
#    'party': 'Republican',
#    'candidate': 'GARY W PARRY',
#    'votes': 2561}],
#  [{'district': 'HD-35',
#    'party': 'Democrat',
#    'candidate': 'KIM KREIDER',
#    'votes': 436}],
#  [{'district': 'HD-36',
#    'party': 'Republican',
#    'candidate': 'GREG KMETZ',
#    'votes': 1600}],
#  [{'district': 'HD-36',
#    'party': 'Democrat',
#    'candidate': 'STAN TAYLOR',
#    'votes': 532}],
#  [{'district': 'HD-37',
#    'party': 'Republican',
#    'candidate': 'SHANE KLAKKEN',
#    'votes': 2478}],
#  [{'district': 'HD-37',
#    'party': 'Democrat',
#    'candidate': 'ANDREA PAYNE',
#    'votes': 664}],
#  [{'district': 'HD-38',
#    'party': 'Republican',
#    'candidate': 'GREG OBLANDER',
#    'votes': 2288},
#   {'district': 'HD-38',
#    'party': 'Republican',
#    'candidate': 'NANCY KEMLER',
#    'votes': 498}],
#  [{'district': 'HD-39',
#    'party': 'Republican',
#    'candidate': 'KERRI SEEKINS-CROWE',
#    'votes': 1497}],
#  [{'district': 'HD-39',
#    'party': 'Democrat',
#    'candidate': 'MELISSA SMITH',
#    'votes': 624}],
#  [{'district': 'HD-40',
#    'party': 'Republican',
#    'candidate': 'MIKE VINTON',
#    'votes': 1197},
#   {'district': 'HD-40',
#    'party': 'Republican',
#    'candidate': 'JOSH VISOCAN',
#    'votes': 601}],
#  [{'district': 'HD-40',
#    'party': 'Democrat',
#    'candidate': 'BOB AUCH',
#    'votes': 484}],
#  [{'district': 'HD-41',
#    'party': 'Republican',
#    'candidate': 'DA WALLOWING BULL',
#    'votes': 418}],
#  [{'district': 'HD-41',
#    'party': 'Democrat',
#    'candidate': 'JADE SOOKTIS',
#    'votes': 370}],
#  [{'district': 'HD-42',
#    'party': 'Republican',
#    'candidate': 'BILL HODGES',
#    'votes': 771}],
#  [{'district': 'HD-42',
#    'party': 'Democrat',
#    'candidate': 'SIDNEY CHIP FITZPATRICK',
#    'votes': 455}],
#  [{'district': 'HD-43',
#    'party': 'Republican',
#    'candidate': 'LARRY BREWSTER',
#    'votes': 1458}],
#  [{'district': 'HD-43',
#    'party': 'Democrat',
#    'candidate': 'ALEXANDER CLARK',
#    'votes': 712}],
#  [{'district': 'HD-44',
#    'party': 'Republican',
#    'candidate': 'KATIE ZOLNIKOV',
#    'votes': 1803}],
#  [{'district': 'HD-45',
#    'party': 'Republican',
#    'candidate': 'KASSIDY OLSON',
#    'votes': 1183}],
#  [{'district': 'HD-45',
#    'party': 'Democrat',
#    'candidate': 'DENISE BAUM',
#    'votes': 1010}],
#  [{'district': 'HD-46',
#    'party': 'Republican',
#    'candidate': 'STARR EMERY',
#    'votes': 988}],
#  [{'district': 'HD-46',
#    'party': 'Democrat',
#    'candidate': 'EMMA KERR CARPENTER',
#    'votes': 922}],
#  [{'district': 'HD-47',
#    'party': 'Republican',
#    'candidate': 'STEPHANIE MONCADA',
#    'votes': 346},
#   {'district': 'HD-47',
#    'party': 'Republican',
#    'candidate': 'THOMAS MAHON',
#    'votes': 315}],
#  [{'district': 'HD-47',
#    'party': 'Democrat',
#    'candidate': 'JAMES REAVIS',
#    'votes': 603}],
#  [{'district': 'HD-48',
#    'party': 'Republican',
#    'candidate': 'CURTIS SCHOMER',
#    'votes': 1018}],
#  [{'district': 'HD-48',
#    'party': 'Democrat',
#    'candidate': 'ANNE ROSS',
#    'votes': 680}],
#  [{'district': 'HD-49',
#    'party': 'Republican',
#    'candidate': 'SHERRY ESSMANN',
#    'votes': 1459}],
#  [{'district': 'HD-49',
#    'party': 'Democrat',
#    'candidate': 'RUDOLF HADEN',
#    'votes': 883}],
#  [{'district': 'HD-50',
#    'party': 'Republican',
#    'candidate': 'ANTHONY NICASTRO',
#    'votes': 1847}],
#  [{'district': 'HD-50',
#    'party': 'Democrat',
#    'candidate': 'SHAWN C GIESICK',
#    'votes': 785}],
#  [{'district': 'HD-51',
#    'party': 'Republican',
#    'candidate': 'JODEE ETCHART',
#    'votes': 1665}],
#  [{'district': 'HD-52',
#    'party': 'Republican',
#    'candidate': 'BILL MERCER',
#    'votes': 2296}],
#  [{'district': 'HD-52',
#    'party': 'Democrat',
#    'candidate': 'CAROLE BOERNER',
#    'votes': 912}],
#  [{'district': 'HD-53',
#    'party': 'Republican',
#    'candidate': 'NELLY NICOL',
#    'votes': 1174},
#   {'district': 'HD-53',
#    'party': 'Republican',
#    'candidate': 'DAVID AUSTIN',
#    'votes': 1065}],
#  [{'district': 'HD-53',
#    'party': 'Democrat',
#    'candidate': 'ELLIE KERNS',
#    'votes': 585}],
#  [{'district': 'HD-54',
#    'party': 'Republican',
#    'candidate': 'LEE DEMING',
#    'votes': 1680}],
#  [{'district': 'HD-55',
#    'party': 'Republican',
#    'candidate': 'BRAD BARKER',
#    'votes': 1519},
#   {'district': 'HD-55',
#    'party': 'Republican',
#    'candidate': 'MARY HORMAN',
#    'votes': 732},
#   {'district': 'HD-55',
#    'party': 'Republican',
#    'candidate': 'LISA BENNETT',
#    'votes': 665}],
#  [{'district': 'HD-55',
#    'party': 'Democrat',
#    'candidate': 'KIM GILLAN',
#    'votes': 960}],
#  [{'district': 'HD-56',
#    'party': 'Republican',
#    'candidate': 'FIONA NAVE',
#    'votes': 2546}],
#  [{'district': 'HD-57',
#    'party': 'Republican',
#    'candidate': 'MARTY MALONE',
#    'votes': 1838}],
#  [{'district': 'HD-57',
#    'party': 'Democrat',
#    'candidate': 'SCOTT ROSENZWEIG',
#    'votes': 1465}],
#  [{'district': 'HD-58',
#    'party': 'Republican',
#    'candidate': 'JASON GUNDERSON',
#    'votes': 1284}],
#  [{'district': 'HD-58',
#    'party': 'Democrat',
#    'candidate': 'JAMIE L ISALY',
#    'votes': 1374},
#   {'district': 'HD-58',
#    'party': 'Democrat',
#    'candidate': 'DEAN WILLIAMSON',
#    'votes': 134}],
#  [{'district': 'HD-59',
#    'party': 'Republican',
#    'candidate': 'MARC GREENDORFER',
#    'votes': 1096}],
#  [{'district': 'HD-59',
#    'party': 'Democrat',
#    'candidate': 'ED STAFMAN',
#    'votes': 1977}],
#  [{'district': 'HD-60',
#    'party': 'Republican',
#    'candidate': 'JERRY JOHNSON',
#    'votes': 1023}],
#  [{'district': 'HD-60',
#    'party': 'Democrat',
#    'candidate': 'ALANAH GRIFFITH',
#    'votes': 1119}],
#  [{'district': 'HD-61',
#    'party': 'Republican',
#    'candidate': 'THOMAS CARLSON',
#    'votes': 135}],
#  [{'district': 'HD-61',
#    'party': 'Democrat',
#    'candidate': 'BECKY EDWARDS',
#    'votes': 700}],
#  [{'district': 'HD-62',
#    'party': 'Republican',
#    'candidate': 'OWEN LANG',
#    'votes': 872}],
#  [{'district': 'HD-62',
#    'party': 'Democrat',
#    'candidate': 'RIO ROLAND',
#    'votes': 448},
#   {'district': 'HD-62',
#    'party': 'Democrat',
#    'candidate': 'JOSHUA A SECKINGER',
#    'votes': 504}],
#  [{'district': 'HD-63',
#    'party': 'Republican',
#    'candidate': 'JOE FLYNN',
#    'votes': 264},
#   {'district': 'HD-63',
#    'party': 'Republican',
#    'candidate': 'MARK LEWIS',
#    'votes': 534}],
#  [{'district': 'HD-63',
#    'party': 'Democrat',
#    'candidate': 'PETER STRAND',
#    'votes': 818},
#   {'district': 'HD-63',
#    'party': 'Democrat',
#    'candidate': 'JOHN HANSEN',
#    'votes': 215}],
#  [{'district': 'HD-64',
#    'party': 'Republican',
#    'candidate': 'JOLENE  CRUM',
#    'votes': 767}],
#  [{'district': 'HD-64',
#    'party': 'Democrat',
#    'candidate': 'KELLY KORTUM',
#    'votes': 1053}],
#  [{'district': 'HD-65',
#    'party': 'Republican',
#    'candidate': 'ESTHER FISHBAUGH',
#    'votes': 1030}],
#  [{'district': 'HD-65',
#    'party': 'Democrat',
#    'candidate': 'ANJA WOOKEYHUFFMAN',
#    'votes': 543},
#   {'district': 'HD-65',
#    'party': 'Democrat',
#    'candidate': 'BRIAN CLOSE',
#    'votes': 860}],
#  [{'district': 'HD-66',
#    'party': 'Republican',
#    'candidate': 'MARLA DAVIS',
#    'votes': 1183}],
#  [{'district': 'HD-66',
#    'party': 'Democrat',
#    'candidate': 'ERIC MATTHEWS',
#    'votes': 1587}],
#  [{'district': 'HD-67',
#    'party': 'Republican',
#    'candidate': 'JEDEDIAH HINKLE',
#    'votes': 1184}],
#  [{'district': 'HD-67',
#    'party': 'Democrat',
#    'candidate': 'CARL ANDERSON',
#    'votes': 627}],
#  [{'district': 'HD-68',
#    'party': 'Republican',
#    'candidate': 'CALEB HINKLE',
#    'votes': 1001},
#   {'district': 'HD-68',
#    'party': 'Republican',
#    'candidate': 'JENNIFER CARLSON',
#    'votes': 699},
#   {'district': 'HD-68',
#    'party': 'Republican',
#    'candidate': 'SCOTT SALES',
#    'votes': 333}],
#  [{'district': 'HD-68',
#    'party': 'Democrat',
#    'candidate': 'ALEXANDER COLAFRANCESCO',
#    'votes': 506}],
#  [{'district': 'HD-69',
#    'party': 'Republican',
#    'candidate': 'KEN WALSH',
#    'votes': 2539}],
#  [{'district': 'HD-70',
#    'party': 'Republican',
#    'candidate': 'MARY ANN NICHOLAS',
#    'votes': 1152},
#   {'district': 'HD-70',
#    'party': 'Republican',
#    'candidate': 'SHANNON MANESS',
#    'votes': 1456},
#   {'district': 'HD-70',
#    'party': 'Republican',
#    'candidate': 'MIKE KLAKKEN',
#    'votes': 366}],
#  [{'district': 'HD-71',
#    'party': 'Republican',
#    'candidate': 'H STEIGER',
#    'votes': 1138}],
#  [{'district': 'HD-71',
#    'party': 'Democrat',
#    'candidate': 'SCOTT P DEMAROIS',
#    'votes': 1881}],
#  [{'district': 'HD-72',
#    'party': 'Republican',
#    'candidate': 'ANDY JOHNSON',
#    'votes': 827}],
#  [{'district': 'HD-72',
#    'party': 'Democrat',
#    'candidate': 'DONAVON HAWK',
#    'votes': 1734}],
#  [{'district': 'HD-73',
#    'party': 'Republican',
#    'candidate': 'ZACH TOMASZEWSKI',
#    'votes': 789}],
#  [{'district': 'HD-73',
#    'party': 'Democrat',
#    'candidate': 'JENNIFER LYNCH',
#    'votes': 1508}],
#  [{'district': 'HD-74',
#    'party': 'Republican',
#    'candidate': 'TRENIN BAYLESS',
#    'votes': 1238}],
#  [{'district': 'HD-74',
#    'party': 'Democrat',
#    'candidate': 'MARC J LEE',
#    'votes': 2235}],
#  [{'district': 'HD-75',
#    'party': 'Republican',
#    'candidate': 'MARTA BERTOGLIO',
#    'votes': 2280}],
#  [{'district': 'HD-75',
#    'party': 'Democrat',
#    'candidate': 'NANCY JANE LIEN',
#    'votes': 1088}],
#  [{'district': 'HD-76',
#    'party': 'Republican',
#    'candidate': 'JOHN FITZPATRICK',
#    'votes': 1466},
#   {'district': 'HD-76',
#    'party': 'Republican',
#    'candidate': 'DAVE KESLER III',
#    'votes': 1369}],
#  [{'district': 'HD-77',
#    'party': 'Republican',
#    'candidate': 'KYLE MCMURRAY',
#    'votes': 1503},
#   {'district': 'HD-77',
#    'party': 'Republican',
#    'candidate': 'JANE GILLETTE',
#    'votes': 1563}],
#  [{'district': 'HD-77',
#    'party': 'Democrat',
#    'candidate': 'JEREMIAH DAWSON',
#    'votes': 547}],
#  [{'district': 'HD-78',
#    'party': 'Republican',
#    'candidate': 'JAMES H BERGSTROM',
#    'votes': 1402},
#   {'district': 'HD-78',
#    'party': 'Republican',
#    'candidate': 'RANDYN GREGG',
#    'votes': 1578}],
#  [{'district': 'HD-78',
#    'party': 'Democrat',
#    'candidate': 'GLENN A LAMBERT',
#    'votes': 525}],
#  [{'district': 'HD-79',
#    'party': 'Republican',
#    'candidate': 'JILL SARK',
#    'votes': 1026},
#   {'district': 'HD-79',
#    'party': 'Republican',
#    'candidate': 'DEMETRI JOSLIN',
#    'votes': 527}],
#  [{'district': 'HD-79',
#    'party': 'Democrat',
#    'candidate': 'ANNE WOODLAND',
#    'votes': 136},
#   {'district': 'HD-79',
#    'party': 'Democrat',
#    'candidate': 'EMILY HARRIS',
#    'votes': 786},
#   {'district': 'HD-79',
#    'party': 'Democrat',
#    'candidate': 'LUKE MUSZKIEWICZ',
#    'votes': 1217}],
#  [{'district': 'HD-80',
#    'party': 'Republican',
#    'candidate': 'RACHEL BURRIGHT',
#    'votes': 1186}],
#  [{'district': 'HD-80',
#    'party': 'Democrat',
#    'candidate': 'MELISSA ROMANO',
#    'votes': 1291}],
#  [{'district': 'HD-81',
#    'party': 'Republican',
#    'candidate': 'DUSTIN SCOTT',
#    'votes': 1337}],
#  [{'district': 'HD-81',
#    'party': 'Democrat',
#    'candidate': 'MARY M CAFERRO',
#    'votes': 1559}],
#  [{'district': 'HD-82',
#    'party': 'Republican',
#    'candidate': 'JOHN LOONEY SR',
#    'votes': 1085}],
#  [{'district': 'HD-82',
#    'party': 'Democrat',
#    'candidate': 'SK ROSSI',
#    'votes': 788},
#   {'district': 'HD-82',
#    'party': 'Democrat',
#    'candidate': 'PETE ELVERUM',
#    'votes': 926}],
#  [{'district': 'HD-83',
#    'party': 'Republican',
#    'candidate': 'CHRISTOPHER ST JEAN',
#    'votes': 429},
#   {'district': 'HD-83',
#    'party': 'Republican',
#    'candidate': 'WES FEIST',
#    'votes': 826}],
#  [{'district': 'HD-83',
#    'party': 'Democrat',
#    'candidate': 'JILL COHENOUR',
#    'votes': 1750}],
#  [{'district': 'HD-84',
#    'party': 'Republican',
#    'candidate': 'JULIE DOOLING',
#    'votes': 1903},
#   {'district': 'HD-84',
#    'party': 'Republican',
#    'candidate': 'JON JACKSON',
#    'votes': 524}],
#  [{'district': 'HD-84',
#    'party': 'Democrat',
#    'candidate': 'DAVID WILLIAMS',
#    'votes': 195},
#   {'district': 'HD-84',
#    'party': 'Democrat',
#    'candidate': 'MICHELE R CREPEAU',
#    'votes': 815}],
#  [{'district': 'HD-85',
#    'party': 'Republican',
#    'candidate': 'MICHELE BINKLEY',
#    'votes': 1462},
#   {'district': 'HD-85',
#    'party': 'Republican',
#    'candidate': 'KATHY LOVE',
#    'votes': 1636}],
#  [{'district': 'HD-85',
#    'party': 'Democrat',
#    'candidate': 'LAURA MAE JACKSON',
#    'votes': 670}],
#  [{'district': 'HD-86',
#    'party': 'Republican',
#    'candidate': 'DAVID BEDEY',
#    'votes': 1883},
#   {'district': 'HD-86',
#    'party': 'Republican',
#    'candidate': 'ROBERT WALLACE',
#    'votes': 611}],
#  [{'district': 'HD-86',
#    'party': 'Democrat',
#    'candidate': 'JEFF KEMPKA',
#    'votes': 870}],
#  [{'district': 'HD-87',
#    'party': 'Republican',
#    'candidate': 'RON MARSHALL',
#    'votes': 2473}],
#  [{'district': 'HD-87',
#    'party': 'Democrat',
#    'candidate': 'TAMMIE MILLIGAN',
#    'votes': 624}],
#  [{'district': 'HD-88',
#    'party': 'Republican',
#    'candidate': 'GREG OVERSTREET',
#    'votes': 1571},
#   {'district': 'HD-88',
#    'party': 'Republican',
#    'candidate': 'KIM DAILEY',
#    'votes': 1328}],
#  [{'district': 'HD-88',
#    'party': 'Democrat',
#    'candidate': 'EVAN SCHROEDEL',
#    'votes': 779}],
#  [{'district': 'HD-89',
#    'party': 'Republican',
#    'candidate': 'LYN HELLEGAARD',
#    'votes': 1252}],
#  [{'district': 'HD-89',
#    'party': 'Democrat',
#    'candidate': 'MARK A THANE',
#    'votes': 1488}],
#  [{'district': 'HD-90',
#    'party': 'Republican',
#    'candidate': 'CURTIS J COCHRAN',
#    'votes': 1034},
#   {'district': 'HD-90',
#    'party': 'Republican',
#    'candidate': 'JEFF STANEK',
#    'votes': 907},
#   {'district': 'HD-90',
#    'party': 'Republican',
#    'candidate': 'STEVEN DELISLE',
#    'votes': 732}],
#  [{'district': 'HD-91',
#    'party': 'Republican',
#    'candidate': 'JOE READ',
#    'votes': 1260}],
#  [{'district': 'HD-91',
#    'party': 'Democrat',
#    'candidate': 'SHELLY R FYANT',
#    'votes': 1270}],
#  [{'district': 'HD-92',
#    'party': 'Republican',
#    'candidate': 'TED MORGAN',
#    'votes': 1025}],
#  [{'district': 'HD-92',
#    'party': 'Democrat',
#    'candidate': 'CONNIE KEOGH',
#    'votes': 1804}],
#  [{'district': 'HD-93',
#    'party': 'Republican',
#    'candidate': 'ROY HANDLEY',
#    'votes': 931}],
#  [{'district': 'HD-93',
#    'party': 'Democrat',
#    'candidate': 'KATIE SULLIVAN',
#    'votes': 1728}],
#  [{'district': 'HD-94',
#    'party': 'Republican',
#    'candidate': 'DELANEY MALMSTEN',
#    'votes': 1100}],
#  [{'district': 'HD-94',
#    'party': 'Democrat',
#    'candidate': 'MARILYN MARLER',
#    'votes': 1866}],
#  [{'district': 'HD-95',
#    'party': 'Republican',
#    'candidate': 'BARBARA W STARMER',
#    'votes': 312}],
#  [{'district': 'HD-95',
#    'party': 'Democrat',
#    'candidate': 'ZOOEY ZEPHYR',
#    'votes': 2209}],
#  [{'district': 'HD-96',
#    'party': 'Republican',
#    'candidate': 'ROBERT LABAIR',
#    'votes': 952}],
#  [{'district': 'HD-96',
#    'party': 'Democrat',
#    'candidate': 'BOB CARTER',
#    'votes': 1495}],
#  [{'district': 'HD-97',
#    'party': 'Republican',
#    'candidate': 'NICK KNOWLES',
#    'votes': 846}],
#  [{'district': 'HD-97',
#    'party': 'Democrat',
#    'candidate': 'MELODY CUNNINGHAM',
#    'votes': 1348},
#   {'district': 'HD-97',
#    'party': 'Democrat',
#    'candidate': 'LISA VERLANIC FOWLER',
#    'votes': 278}],
#  [{'district': 'HD-97',
#    'party': 'Libertarian',
#    'candidate': 'RICHARD L ARMERDING',
#    'votes': 5}],
#  [{'district': 'HD-98',
#    'party': 'Republican',
#    'candidate': 'JACE BEARD',
#    'votes': 853}],
#  [{'district': 'HD-98',
#    'party': 'Democrat',
#    'candidate': 'JONATHAN KARLEN',
#    'votes': 1376}],
#  [{'district': 'HD-99',
#    'party': 'Republican',
#    'candidate': 'RYAN DARLING',
#    'votes': 1017}],
#  [{'district': 'HD-99',
#    'party': 'Democrat',
#    'candidate': 'TOM FRANCE',
#    'votes': 1536}],
#  [{'district': 'HD-100',
#    'party': 'Republican',
#    'candidate': 'CHRISTOPHER PAUL BUCKLES',
#    'votes': 353}],
#  [{'district': 'HD-100',
#    'party': 'Democrat',
#    'candidate': 'SJ HOWELL',
#    'votes': 1230},
#   {'district': 'HD-100',
#    'party': 'Democrat',
#    'candidate': 'TIM GARRISON',
#    'votes': 477}]]

# %%
tall = pd.DataFrame([item for district in output for item in district])

# %%
tall
# Out:
#     district       party                 candidate  votes
# 0       SD-2  Republican                DOUG ADAMS   2318
# 1       SD-2    Democrat                 DAVE FERN   2344
# 2       SD-3  Republican                CARL GLIMM   3802
# 3       SD-3    Democrat            ANGELA KENNEDY   1394
# 4       SD-5  Republican           MARQUIS L LAUDE   1427
# ..       ...         ...                       ...    ...
# 297    HD-99  Republican              RYAN DARLING   1017
# 298    HD-99    Democrat                TOM FRANCE   1536
# 299   HD-100  Republican  CHRISTOPHER PAUL BUCKLES    353
# 300   HD-100    Democrat                 SJ HOWELL   1230
# 301   HD-100    Democrat              TIM GARRISON    477
#
# [302 rows x 4 columns]

# %%
def summarize(row):
    total_votes = row['votes'].sum()
    gop_votes = row[row['party'] == 'Republican']['votes'].sum()
    dem_votes = row[row['party'] == 'Democrat']['votes'].sum()
    return pd.Series({
        'total_primary_votes': total_votes,
        'fraction_primary_votes_to_gop': gop_votes / total_votes,
        'gop_primary_votes': gop_votes,
        'gop_candidates': ', '.join(row[row['party'] == 'Republican']['candidate']),
        'dem_primary_votes': dem_votes,
        'dem_candidates': ', '.join(row[row['party'] == 'Democrat']['candidate']),
        
    }, index=['total_primary_votes','fraction_primary_votes_to_gop','gop_primary_votes','gop_candidates','dem_primary_votes','dem_candidates'])

summary = tall.groupby(['district']).apply(summarize).sort_values('fraction_primary_votes_to_gop', ascending=False)

# %%
# Merge in Daves districting scores
daves_hd = pd.read_csv('../inputs/daves-redistricting/mt-house-district-statistics.csv',index_col=False)
daves_hd['daves_score_r_plus'] = round(100*(daves_hd['Rep'] - daves_hd['Dem']))
daves_hd['district'] = 'HD-' + daves_hd['ID']

daves_sd = pd.read_csv('../inputs/daves-redistricting/mt-senate-district-statistics.csv',index_col=False)
daves_sd['daves_score_r_plus'] = round(100*(daves_sd['Rep'] - daves_sd['Dem']))
daves_sd['district'] = 'SD-' + daves_sd['ID']

daves = daves_hd.append(daves_sd)
daves
# Out:
# /var/folders/gk/_q4g8knj7354h1qcc0gsdcq00000gp/T/ipykernel_4821/2078633442.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   daves = daves_hd.append(daves_sd)
#      ID  Total Pop  Deviation     Dem     Rep     Oth  Total VAP   White  \
# 0    Un          0     0.0000  0.0000  0.0000  0.0000          0  0.0000
# 1     1      10823    -0.0004  0.2533  0.7303  0.0165       8854  0.9086
# 2     2      10904     0.0071  0.2565  0.7236  0.0199       8744  0.9145
# 3     3      10764    -0.0058  0.5301  0.4500  0.0198       8873  0.9167
# 4     4      10774    -0.0049  0.4747  0.5022  0.0231       8472  0.9055
# ..  ...        ...        ...     ...     ...     ...        ...     ...
# 47   47      21728     0.0034  0.6112  0.3683  0.0204      16843  0.8748
# 48   48      21513    -0.0065  0.7127  0.2612  0.0261      18039  0.8170
# 49   49      21621    -0.0015  0.5886  0.3815  0.0299      17340  0.8600
# 50   50      21473    -0.0084  0.6649  0.3069  0.0282      17611  0.8659
# 51  NaN      21654     0.0698  0.4265  0.5509  0.0225      17002  0.8558
#
#     Minority  Hispanic   Black   Asian  Native  Pacific  daves_score_r_plus  \
# 0     0.0000    0.0000  0.0000  0.0000  0.0000   0.0000                 0.0
# 1     0.0914    0.0270  0.0049  0.0089  0.0374   0.0029                48.0
# 2     0.0855    0.0183  0.0045  0.0091  0.0396   0.0027                47.0
# 3     0.0833    0.0275  0.0036  0.0132  0.0267   0.0021                -8.0
# 4     0.0945    0.0238  0.0057  0.0111  0.0360   0.0035                 3.0
# ..       ...       ...     ...     ...     ...      ...                 ...
# 47    0.1252    0.0499  0.0081  0.0234  0.0373   0.0026               -24.0
# 48    0.1830    0.0971  0.0121  0.0206  0.0466   0.0024               -45.0
# 49    0.1400    0.0370  0.0128  0.0221  0.0585   0.0026               -21.0
# 50    0.1341    0.0393  0.0135  0.0217  0.0485   0.0038               -36.0
# 51    0.1442    0.0352  0.0088  0.0136  0.0778   0.0023                12.0
#
#    district
# 0     HD-Un
# 1      HD-1
# 2      HD-2
# 3      HD-3
# 4      HD-4
# ..      ...
# 47    SD-47
# 48    SD-48
# 49    SD-49
# 50    SD-50
# 51      NaN
#
# [154 rows x 16 columns]

# %%
summary = summary.merge(daves[['district','daves_score_r_plus', 'Native']], left_on='district', right_on='district')

# %%
summary.to_csv('../outputs/2024-legislative-primaries-by-party-vote.csv', index=False)
